# %% [markdown]
# # Natural Language Processing Coursework
#
# Name - **Venkatesh Nagasubramanian**
# e-mail - vn00197@surrey.ac.uk
# URN - 6721597

# %% [markdown]
# # 1. Data Analysis and Visualization
#
# Run the code cell below to view all the outputs of the file "1 - Data Analysis and visualization.ipynb"
#
# Press ``Shift + O`` to view all outputs

# %%
import time
start = time.time()
# %run "1 - Data Analysis and visualization.ipynb"
print("Runtime -", time.time()-start, "seconds")
# Out:
# No config specified, defaulting to: go_emotions/simplified
# Found cached dataset go_emotions (C:/Users/venka/.cache/huggingface/datasets/go_emotions/simplified/0.0.0/2637cfdd4e64d30249c3ed2150fa2b9d279766bfcd6a809b9f085c61a90d776d)
# [('NAME', 9438), ('s', 2840), ('Thank', 2738), ('love', 2404), ('one', 2332)]
# Runtime - 28.52660894393921 seconds

# %% [markdown]
# # 2. Experiment #1 - Data Preprocessing
# Run the code cell below to view all the outputs of the file "2 - Experiment #1.ipynb"
#
# Press ``Shift + O`` to view all outputs

# %%
start = time.time()
# %run "2 - Experiment #1.ipynb"
print("Runtime -", time.time()-start, "seconds")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\venka\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\venka\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\venka\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\venka\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# Variation #1 Using unigrams , lemmatization, and removal of additional stopwords.
# Epoch 1/20
# 954/954 [==============================] - 12s 6ms/step - loss: 1.9827 - accuracy: 0.3893 - val_loss: 1.7970 - val_accuracy: 0.4362
# Epoch 2/20
# ...

# %% [markdown]
# # 3. Experiment #2 - NLP Algorithms / Techniques
# Run the code cell below to view all the outputs of the file "3 - Experiment #2.ipynb"
#
# Press ``Shift + O`` to view all outputs

# %%
start = time.time()
# %run "3 - Experiment #2.ipynb"
print("Runtime -", time.time()-start, "seconds")
# Out:
# Variation #1 - XGBoost
# Variation #2 - Bidirectional LSTM
# Epoch 1/20
# 954/954 [==============================] - 6s 4ms/step - loss: 1.9837 - accuracy: 0.3909 - val_loss: 1.7959 - val_accuracy: 0.4405
# Epoch 2/20
# 954/954 [==============================] - 4s 4ms/step - loss: 1.7965 - accuracy: 0.4405 - val_loss: 1.7406 - val_accuracy: 0.4601
# Epoch 3/20
# 954/954 [==============================] - 4s 4ms/step - loss: 1.7533 - accuracy: 0.4566 - val_loss: 1.7209 - val_accuracy: 0.4669
# Epoch 4/20
# 954/954 [==============================] - 4s 4ms/step - loss: 1.7142 - accuracy: 0.4624 - val_loss: 1.6988 - val_accuracy: 0.4657
# Epoch 5/20
# 954/954 [==============================] - 4s 4ms/step - loss: 1.6930 - accuracy: 0.4669 - val_loss: 1.6881 - val_accuracy: 0.4680
# Epoch 6/20
# 954/954 [==============================] - 4s 5ms/step - loss: 1.6760 - accuracy: 0.4731 - val_loss: 1.6753 - val_accuracy: 0.4714
# Epoch 7/20
# ...

# %% [markdown]
# # 4. Experiment #3 - Text vectorization
# Run the code cell below to view all the outputs of the file "4 - Experiment #3.ipynb"
#
# Press ``Shift + O`` to view all outputs

# %%
start = time.time()
# %run "4 - Experiment #3.ipynb"
print("Runtime -", time.time()-start, "seconds")
# Out:
# Variation #1 - Word2Vec
# Time elapsed: 16.671412706375122
# Variation #2 - GloVe
# Time elapsed: 93.86258172988892
# Variation #1 - Word2Vec
# Epoch 1/20
# 954/954 [==============================] - 7s 5ms/step - loss: 1.9876 - accuracy: 0.3897 - val_loss: 1.7929 - val_accuracy: 0.4405
# Epoch 2/20
# 954/954 [==============================] - 5s 5ms/step - loss: 1.7975 - accuracy: 0.4385 - val_loss: 1.7491 - val_accuracy: 0.4510
# Epoch 3/20
# 954/954 [==============================] - 4s 5ms/step - loss: 1.7462 - accuracy: 0.4551 - val_loss: 1.7188 - val_accuracy: 0.4628
# Epoch 4/20
# 954/954 [==============================] - 4s 4ms/step - loss: 1.7182 - accuracy: 0.4604 - val_loss: 1.7014 - val_accuracy: 0.4691
# Epoch 5/20
# 954/954 [==============================] - 4s 5ms/step - loss: 1.6951 - accuracy: 0.4651 - val_loss: 1.6867 - val_accuracy: 0.4750
# Epoch 6/20
# ...

# %% [markdown]
# # 5. Experiment #4 - Train/test splitting
# Run the code cell below to view all the outputs of the file "5 - Experiment #4.ipynb"
#
# Press ``Shift + O`` to view all outputs

# %%
start = time.time()
# %run "5 - Experiment #4.ipynb"
print("Runtime -", time.time()-start, "seconds")
# Out:
# Variation #1
# Epoch 1/20
# 954/954 [==============================] - 8s 6ms/step - loss: 1.9922 - accuracy: 0.3869 - val_loss: 1.7937 - val_accuracy: 0.4377
# Epoch 2/20
# 954/954 [==============================] - 5s 5ms/step - loss: 1.7990 - accuracy: 0.4374 - val_loss: 1.7440 - val_accuracy: 0.4532
# Epoch 3/20
# 954/954 [==============================] - 4s 5ms/step - loss: 1.7505 - accuracy: 0.4514 - val_loss: 1.7171 - val_accuracy: 0.4657
# Epoch 4/20
# 954/954 [==============================] - 5s 5ms/step - loss: 1.7202 - accuracy: 0.4609 - val_loss: 1.6970 - val_accuracy: 0.4679
# Epoch 5/20
# 954/954 [==============================] - 4s 4ms/step - loss: 1.6964 - accuracy: 0.4665 - val_loss: 1.6871 - val_accuracy: 0.4701
# Epoch 6/20
# 954/954 [==============================] - 5s 5ms/step - loss: 1.6751 - accuracy: 0.4723 - val_loss: 1.6745 - val_accuracy: 0.4749
# Epoch 7/20
# ...
